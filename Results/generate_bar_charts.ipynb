# %% [markdown]
# ##### Author: Rylee Albrecht

# %%
import pandas as pd

data = [
    {'Class': "Gestational", 'Model': "LDA", 'FP': 0, 'FN': 69, 'Total': 69},
    {'Class': "No Diabetes", 'Model': "LDA", 'FP': 282, 'FN': 1455, 'Total': 1937},
    {'Class': "Pre-Diabetes", 'Model': "LDA", 'FP': 3249, 'FN': 2847, 'Total': 8105},
    {'Class': "Type 1", 'Model': "LDA", 'FP': 0, 'FN': 31, 'Total': 31},
    {'Class': "Type 2", 'Model': "LDA", 'FP': 2742, 'FN': 1871, 'Total': 14858},
    {'Class': "Gestational", 'Model': "QDA", 'FP': 0, 'FN': 69, 'Total': 69},
    {'Class': "No Diabetes", 'Model': "QDA", 'FP': 1012, 'FN': 874, 'Total': 1937},
    {'Class': "Pre-Diabetes", 'Model': "QDA", 'FP': 2941, 'FN': 2871, 'Total': 8105},
    {'Class': "Type 1", 'Model': "QDA", 'FP': 0, 'FN': 31, 'Total': 31},
    {'Class': "Type 2", 'Model': "QDA", 'FP': 2354, 'FN': 2246, 'Total': 14858},
    {'Class': "Gestational", 'Model': "KNN", 'FP': 0, 'FN': 69, 'Total': 69},
    {'Class': "No Diabetes", 'Model': "KNN", 'FP': 733, 'FN': 1101, 'Total': 1937},
    {'Class': "Pre-Diabetes", 'Model': "KNN", 'FP': 3434, 'FN': 2518, 'Total': 8105},
    {'Class': "Type 1", 'Model': "KNN", 'FP': 0, 'FN': 31, 'Total': 31},
    {'Class': "Type 2", 'Model': "KNN", 'FP': 2103, 'FN': 2551, 'Total': 14858},
    {'Class': "Gestational", 'Model': "Logistic Regression", 'FP': 0, 'FN': 69, 'Total': 69},
    {'Class': "No Diabetes", 'Model': "Logistic Regression", 'FP': 0, 'FN': 1937, 'Total': 1937},
    {'Class': "Pre-Diabetes", 'Model': "Logistic Regression", 'FP': 4430, 'FN': 2008, 'Total': 8105},
    {'Class': "Type 1", 'Model': "Logistic Regression", 'FP': 0, 'FN': 31, 'Total': 31},
    {'Class': "Type 2", 'Model': "Logistic Regression", 'FP': 2460, 'FN': 2075, 'Total': 14858},
    {'Class': "Gestational", 'Model': "Naive Bayes", 'FP': 0, 'FN': 69, 'Total': 69},
    {'Class': "No Diabetes", 'Model': "Naive Bayes", 'FP': 751, 'FN': 1089, 'Total': 1937},
    {'Class': "Pre-Diabetes", 'Model': "Naive Bayes", 'FP': 3138, 'FN': 2713, 'Total': 8105},
    {'Class': "Type 1", 'Model': "Naive Bayes", 'FP': 0, 'FN': 31, 'Total': 31},
    {'Class': "Type 2", 'Model': "Naive Bayes", 'FP': 2277, 'FN': 2290, 'Total': 14858},
    {'Class': "Gestational", 'Model': "SVM", 'FP': 282, 'FN': 68, 'Total': 69},
    {'Class': "No Diabetes", 'Model': "SVM", 'FP': 2368, 'FN': 398, 'Total': 1937},
    {'Class': "Pre-Diabetes", 'Model': "SVM", 'FP': 3670, 'FN': 2713, 'Total': 8105},
    {'Class': "Type 1", 'Model': "SVM", 'FP': 25, 'FN': 31, 'Total': 31},
    {'Class': "Type 2", 'Model': "SVM", 'FP': 3999, 'FN': 864, 'Total': 14858},
]

df = pd.DataFrame(data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute FP-FN counts
df['FP_minus_FN_count'] = df['FP'] - df['FN']

# Create a larger figure
plt.figure(figsize=(10, 6))

# Plot
sns.barplot(data=df, x='Class', y='FP_minus_FN_count', hue='Model')
plt.title('False Positives minus False Negatives per Class', fontsize=18)
plt.xticks(rotation=35, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
